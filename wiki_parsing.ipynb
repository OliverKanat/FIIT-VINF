# %%
import re
import io
import time

# %% [markdown]
# ### Parsovanie rozlisovacich stranok z SQL dumpu riadok po riadku

# %%
DISAMBIGUATION_REGEX = "\([0-9]*,[0-9]*,.{0,50}_\(rozlišovacia_stránka\)"
disambiguation_pages = {}

with open("skwiki-latest-page.sql", 'rb') as f:
    for line in f:
        line = line.decode('utf-8')
        
        pages = re.findall(DISAMBIGUATION_REGEX, line)
        for page in pages:
            page_id = page.split(",")[0].split("(")[1]
            page_name = page.split(",")[2][1:]
            disambiguation_pages[page_id] = page_name
            
disambiguation_pages
# Out:
# {'5843': 'Merkúr_(rozlišovacia_stránka)',
#  '5866': 'Mars_(rozlišovacia_stránka)',
#  '5871': 'Saturn_(rozlišovacia_stránka)',
#  '6088': 'Venuša_(rozlišovacia_stránka)',
#  '6507': 'Mesiac_(rozlišovacia_stránka)',
#  '6727': 'Neptún_(rozlišovacia_stránka)',
#  '6731': 'Pluto_(rozlišovacia_stránka)',
#  '6734': 'Jupiter_(rozlišovacia_stránka)',
#  '8237': 'Stupava_(rozlišovacia_stránka)',
#  '10084': 'Pôda_(rozlišovacia_stránka)',
#  '13826': 'Opera_(rozlišovacia_stránka)',
#  '14217': 'Hviezdna_sústava_(rozlišovacia_stránka)',
#  '14600': 'Pyramída_(rozlišovacia_stránka)',
#  '14601': 'Ihlan_(rozlišovacia_stránka)',
#  '14919': 'Apple_(rozlišovacia_stránka)',
#  '18926': 'Bunka_(rozlišovacia_stránka)',
#  '21733': 'Loď_(rozlišovacia_stránka)',
#  '23406': 'Írsko_(rozlišovacia_stránka)',
#  '23407': 'Írsko_(rozlišovacia_stránka)',
#  '27548': 'Potok_(rozlišovacia_stránka)',
#  '28217': 'Mexiko_(rozlišovacia_stránka)',
#  '30857': 'Nitra_(rozlišovacia_stránka)',
#  '31645': 'Čechy_(rozlišovacia_stránka)',
#  '33145': 'Čína_(rozlišovacia_stránka)',
#  '34202': 'Hviezdna_sústava_(rozlišovacia_stránka)',
#  '34649': 'Bajkonur_(rozlišovacia_stránka)',
#  '34798': 'Indus_(rozlišovacia_stránka)',
#  '35906': 'Pascal_(rozlišovacia_stránka)',
#  '35972': 'Lipany_(rozlišovacia_stránka)',
#  '36107': 'Najsvätejšia_Trojica_(rozlišovacia_stránka)',
#  '36443': 'Leicester_(rozlišovacia_stránka)',
#  '37125': 'Benátky_(rozlišovacia_stránka)',
#  '37197': 'Madrid_(rozlišovacia_stránka)',
#  '37223': 'Cyprus_(rozlišovacia_stránka)',
#  '37700': 'Elbrus_(rozlišovacia_stránka)',
#  '37717': 'Monako_(rozlišovacia_stránka)',
#  '37736': 'Zem_(rozlišovacia_stránka)',
#  '37885': 'Okno_(rozlišovacia_stránka)',
#  '38883': 'Drotár_(rozlišovacia_stránka)',
#  '39038': 'Chicago_(rozlišovacia_stránka)',
#  '39079': 'Chicago_(rozlišovacia_stránka)',
#  '40132': 'Vajce_(rozlišovacia_stránka)',
#  '40152': 'Búrka_(rozlišovacia_stránka)',
#  '40605': 'Mapa_(rozlišovacia_stránka)',
#  '40643': 'Röntgen_(rozlišovacia_stránka)',
#  '41039': 'Parabola_(rozlišovacia_stránka)',
#  '41819': 'Apollo_13_(rozlišovacia_stránka)',
#  '44164': 'Mechanika_(rozlišovacia_stránka)',
#  '44642': 'Európa_(rozlišovacia_stránka)',
#  '46364': 'Ottawa_(rozlišovacia_stránka)',
#  '46382': 'Peru_(rozlišovacia_stránka)',
#  '50214': 'Rieka_(rozlišovacia_stránka)',
#  '51656': 'Žila_(rozlišovacia_stránka)',
#  '51854': 'Strana_zelených_(rozlišovacia_stránka)',
#  '52198': 'Sila_(rozlišovacia_stránka)',
#  '52784': 'Ikona_(rozlišovacia_stránka)',
#  '58151': 'Ružová_(rozlišovacia_stránka)',
#  '58173': 'Brazília_(rozlišovacia_stránka)',
#  '58348': 'Andorra_(rozlišovacia_stránka)',
#  '64584': 'Scenár_(rozlišovacia_stránka)',
#  '64757': 'Kryštál_(rozlišovacia_stránka)',
#  '65628': 'Plazy_(rozlišovacia_stránka)',
#  '72657': 'Röntgen_(rozlišovacia_stránka)',
#  '73108': 'Hodváb_(rozlišovacia_stránka)',
#  '75051': 'Chorváti_(rozlišovacia_stránka)',
#  '75186': 'Granada_(rozlišovacia_stránka)',
#  '75192': 'Grenada_(rozlišovacia_stránka)',
#  '75591': 'Maryland_(rozlišovacia_stránka)',
#  '77254': 'Grafit_(rozlišovacia_stránka)',
#  '81326': 'Tripolis_(rozlišovacia_stránka)',
#  '81488': 'Niger_(rozlišovacia_stránka)',
#  '81981': 'Magnetizmus_(rozlišovacia_stránka)',
#  '83431': 'Stalingrad_(rozlišovacia_stránka)',
#  '83645': 'Karpaty_(rozlišovacia_stránka)',
#  '83702': 'Liverpool_(rozlišovacia_stránka)',
#  '83703': 'Aglomerácia_(rozlišovacia_stránka)',
#  '84717': 'Raketa_(rozlišovacia_stránka)',
#  '87088': 'Black_Sabbath_(rozlišovacia_stránka)',
#  '87317': 'Oheň_(rozlišovacia_stránka)',
#  '87474': 'Alexandria_(rozlišovacia_stránka)',
#  '87736': 'Godiva_(rozlišovacia_stránka)',
#  '88672': 'Madeira_(rozlišovacia_stránka)',
#  '88964': 'Dolina_(rozlišovacia_stránka)',
#  '91876': 'Čítanie_(rozlišovacia_stránka)',
#  '95506': 'Korózia_(rozlišovacia_stránka)',
#  '102767': 'USA_(rozlišovacia_stránka)',
#  '103902': 'Eos_(rozlišovacia_stránka)',
#  '104144': 'Pokrok_(rozlišovacia_stránka)',
#  '104194': 'Mantra_(rozlišovacia_stránka)',
#  '104318': 'Sandberg_(rozlišovacia_stránka)',
#  '105094': 'Kľačany_(rozlišovacia_stránka)',
#  '105675': 'Hrabovec_(rozlišovacia_stránka)',
#  '106391': 'Galícia_(rozlišovacia_stránka)',
#  '106396': 'Kastília_(rozlišovacia_stránka)',
#  '106658': 'Raj_(rozlišovacia_stránka)',
#  '106831': 'Dielo_(rozlišovacia_stránka)',
#  '107364': 'Detroit_(rozlišovacia_stránka)',
#  '107531': 'Minneapolis_(rozlišovacia_stránka)',
#  '107569': 'São_Paulo_(rozlišovacia_stránka)',
#  '107589': 'Toronto_(rozlišovacia_stránka)',
#  '107590': 'Montreal_(rozlišovacia_stránka)',
#  '108264': 'Železnica_(rozlišovacia_stránka)',
#  '108757': 'Satan_(rozlišovacia_stránka)',
#  '109162': 'Arminius_(rozlišovacia_stránka)',
#  '109384': 'Santos_(rozlišovacia_stránka)',
#  '109402': 'Architektúra_(rozlišovacia_stránka)',
#  '109446': 'Trstená_(rozlišovacia_stránka)',
#  '109765': 'Ústava_(rozlišovacia_stránka)',
#  '110148': 'Močiar_(rozlišovacia_stránka)',
#  '111298': 'Dopyt_(rozlišovacia_stránka)',
#  '111303': 'Kamerun_(rozlišovacia_stránka)',
#  '111335': 'Patna_(rozlišovacia_stránka)',
#  '111368': 'Oko_(rozlišovacia_stránka)',
#  '111389': 'Ruská_Voľa_(rozlišovacia_stránka)',
#  '111432': 'Jed_(rozlišovacia_stránka)',
#  '111705': 'Circa_(rozlišovacia_stránka)',
#  '112123': 'Polianka_(rozlišovacia_stránka)',
#  '112128': 'Žipov_(rozlišovacia_stránka)',
#  '112274': 'Veľký_kaňon_(rozlišovacia_stránka)',
#  '112866': 'Straka_(rozlišovacia_stránka)',
#  '112876': 'Zaklínač_(rozlišovacia_stránka)',
#  '113212': 'Ostrov_(rozlišovacia_stránka)',
#  '113421': 'Viking_(rozlišovacia_stránka)',
#  '113975': 'PNG_(rozlišovacia_stránka)',
#  '113991': 'PNG_(rozlišovacia_stránka)',
#  '114521': 'Sol_(rozlišovacia_stránka)',
#  '115428': 'Lupa_(rozlišovacia_stránka)',
#  '115593': 'Å_(rozlišovacia_stránka)',
#  '115698': 'Oxford_(rozlišovacia_stránka)',
#  '117194': 'Bitka_o_Britániu_(rozlišovacia_stránka)',
#  '117617': 'Hestia_(rozlišovacia_stránka)',
#  '118864': 'Energia_(rozlišovacia_stránka)',
#  '119062': 'Perec_(rozlišovacia_stránka)',
#  '119812': 'Film_(rozlišovacia_stránka)',
#  '121217': 'Préria_(rozlišovacia_stránka)',
#  '122258': 'Limbach_(rozlišovacia_stránka)',
#  '123134': 'Bratislava_(rozlišovacia_stránka)',
#  '123140': 'Dub_(rozlišovacia_stránka)',
#  '124117': 'Štvorec_(rozlišovacia_stránka)',
#  '124366': 'Utrecht_(rozlišovacia_stránka)',
#  '124434': 'Lama_(rozlišovacia_stránka)',
#  '124558': 'Jar_(rozlišovacia_stránka)',
#  '127475': 'Železník_(rozlišovacia_stránka)',
#  '128359': 'Schwechat_(rozlišovacia_stránka)',
#  '128525': 'Aerolit_(rozlišovacia_stránka)',
#  '128616': 'Ain_(rozlišovacia_stránka)',
#  '129162': 'James_Bond_(rozlišovacia_stránka)',
#  '129700': 'Weimar_(rozlišovacia_stránka)',
#  '130894': 'Tirana_(rozlišovacia_stránka)',
#  '131481': 'Rok_(rozlišovacia_stránka)',
#  '131788': 'Perla_(rozlišovacia_stránka)',
#  '136618': 'Trnava_(rozlišovacia_stránka)',
#  '136710': 'Biela_(rozlišovacia_stránka)',
#  '138840': 'Kniha_(rozlišovacia_stránka)',
#  '138949': 'Ur_(rozlišovacia_stránka)',
#  '140673': 'Catania_(rozlišovacia_stránka)',
#  '141042': 'Arizona_(rozlišovacia_stránka)',
#  '141191': 'Moldavsko_(rozlišovacia_stránka)',
#  '141192': 'Moldavsko_(rozlišovacia_stránka)',
#  '141220': 'Sevilla_(rozlišovacia_stránka)',
#  '141222': 'Palermo_(rozlišovacia_stránka)',
#  '141223': 'Valladolid_(rozlišovacia_stránka)',
#  '141717': 'Gitara_(rozlišovacia_stránka)',
#  '141817': 'Hliník_(rozlišovacia_stránka)',
#  '142271': 'Maine_(rozlišovacia_stránka)',
#  '142365': 'Žilina_(rozlišovacia_stránka)',
#  '142958': 'Vanda_(rozlišovacia_stránka)',
#  '143007': 'Hviezda_(rozlišovacia_stránka)',
#  '143890': 'Thor_(rozlišovacia_stránka)',
#  '144134': 'Buenos_Aires_(rozlišovacia_stránka)',
#  '144258': 'Slaná_(rozlišovacia_stránka)',
#  '144414': 'Altiplano_(rozlišovacia_stránka)',
#  '144438': 'Otec_(rozlišovacia_stránka)',
#  '144474': 'Brownov_pohyb_(rozlišovacia_stránka)',
#  '144797': 'San_Francisco_(rozlišovacia_stránka)',
#  '145663': 'Budín_(rozlišovacia_stránka)',
#  '147129': 'Biely_dom_(rozlišovacia_stránka)',
#  '148177': 'Jáger_(rozlišovacia_stránka)',
#  '148381': 'Samba_(rozlišovacia_stránka)',
#  '149528': 'Hatifusi_(rozlišovacia_stránka)',
#  '149709': 'Samara_(rozlišovacia_stránka)',
#  '151220': 'Svätý_Ondrej_(rozlišovacia_stránka)',
#  '152481': 'Sofia_(rozlišovacia_stránka)',
#  '153191': 'Somár_(rozlišovacia_stránka)',
#  '154359': 'Tulipán_(rozlišovacia_stránka)',
#  '154364': 'Peklo_(rozlišovacia_stránka)',
#  '154942': 'Republika_(rozlišovacia_stránka)',
#  '155305': 'Finlandia_(rozlišovacia_stránka)',
#  '155992': 'Opátka_(rozlišovacia_stránka)',
#  '156706': 'Maslo_(rozlišovacia_stránka)',
#  '157197': 'Spojené_štáty_(rozlišovacia_stránka)',
#  '157571': 'Banské_(rozlišovacia_stránka)',
#  '157574': 'Hlboké_(rozlišovacia_stránka)',
#  '159577': 'Mir_(rozlišovacia_stránka)',
#  '160552': 'Štvrtok_(rozlišovacia_stránka)',
#  '160554': 'Streda_(rozlišovacia_stránka)',
#  '160571': 'Vodník_(rozlišovacia_stránka)',
#  '160720': 'Bursa_(rozlišovacia_stránka)',
#  '160820': 'More_(rozlišovacia_stránka)',
#  '161695': 'Dvorníky_(rozlišovacia_stránka)',
#  '162806': 'Helena_(rozlišovacia_stránka)',
#  '164166': 'Andrew_Johnson_(rozlišovacia_stránka)',
#  '164488': 'Budiš_(rozlišovacia_stránka)',
#  '164625': 'Dallas_(rozlišovacia_stránka)',
#  '165230': 'Arkádia_(rozlišovacia_stránka)',
#  '165938': 'Most_(rozlišovacia_stránka)',
#  '166074': 'Čierna_(rozlišovacia_stránka)',
#  '166727': 'Šikoku_(rozlišovacia_stránka)',
#  '166729': 'Jokohama_(rozlišovacia_stránka)',
#  '166732': 'Dav_(rozlišovacia_stránka)',
#  '167418': 'Maska_(rozlišovacia_stránka)',
#  '167464': 'Prince_(rozlišovacia_stránka)',
#  '168811': 'Galadriel_(rozlišovacia_stránka)',
#  '171569': 'Portsmouth_(rozlišovacia_stránka)',
#  '173688': 'Evita_(rozlišovacia_stránka)',
#  '177019': 'Elf_(rozlišovacia_stránka)',
#  '177854': 'Diamant_(rozlišovacia_stránka)',
#  '182986': 'Rusko_(rozlišovacia_stránka)',
#  '184635': 'Halloween_(rozlišovacia_stránka)',
#  '185525': 'Mydlo_(rozlišovacia_stránka)',
#  '187703': 'Holandské_kráľovstvo_(rozlišovacia_stránka)',
#  '188930': 'Dáni_(rozlišovacia_stránka)',
#  '190834': 'Duša_(rozlišovacia_stránka)',
#  '190967': 'Rebro_(rozlišovacia_stránka)',
#  '191060': 'Robin_Hood_(rozlišovacia_stránka)',
#  '194290': 'Rodina_(rozlišovacia_stránka)',
#  '194624': 'Moskva_(rozlišovacia_stránka)',
#  '194760': 'Mali_(rozlišovacia_stránka)',
#  '195292': 'Slovany_(rozlišovacia_stránka)',
#  '195622': 'Kardam_(rozlišovacia_stránka)',
#  '195623': 'Tervel_(rozlišovacia_stránka)',
#  '195624': 'Asparuch_(rozlišovacia_stránka)',
#  '195627': 'Ivajlo_(rozlišovacia_stránka)',
#  '195676': 'Bansko_(rozlišovacia_stránka)',
#  '197449': 'Louisiana_(rozlišovacia_stránka)',
#  '197807': 'Ruda_(rozlišovacia_stránka)',
#  '198135': 'Štát_(rozlišovacia_stránka)',
#  '199265': 'Pokánie_(rozlišovacia_stránka)',
#  '200667': 'Nice_(rozlišovacia_stránka)',
#  '200968': 'Máj_(rozlišovacia_stránka)',
#  '201010': 'Uhlík_(rozlišovacia_stránka)',
#  '201691': 'Piesok_(rozlišovacia_stránka)',
#  '201887': 'Zvolen_(rozlišovacia_stránka)',
#  '201901': 'Trenčín_(rozlišovacia_stránka)',
#  '202355': 'Život_(rozlišovacia_stránka)',
#  '202356': 'Senica_(rozlišovacia_stránka)',
#  '202359': 'Sloboda_(rozlišovacia_stránka)',
#  '202656': 'Poprad_(rozlišovacia_stránka)',
#  '204819': 'Letún_(rozlišovacia_stránka)',
#  '205228': 'Zenit_(rozlišovacia_stránka)',
#  '206212': 'Kváder_(rozlišovacia_stránka)',
#  '206469': 'Uhlopriečka_(rozlišovacia_stránka)',
#  '207413': 'Tennessee_(rozlišovacia_stránka)',
#  '208267': 'Červená_armáda_(rozlišovacia_stránka)',
#  '209545': 'Duch_času_(rozlišovacia_stránka)',
#  '210170': 'Ohio_(rozlišovacia_stránka)',
#  '213665': 'Para_(rozlišovacia_stránka)',
#  '213673': 'Mýtus_(rozlišovacia_stránka)',
#  '217292': 'Sunshine_(rozlišovacia_stránka)',
#  '217358': 'Kiahne_(rozlišovacia_stránka)',
#  '218209': 'Istota_(rozlišovacia_stránka)',
#  '218465': 'Gaal_(rozlišovacia_stránka)',
#  '220339': 'Krk_(rozlišovacia_stránka)',
#  '220360': 'Lambda_(rozlišovacia_stránka)',
#  '220387': 'Spiš_(rozlišovacia_stránka)',
#  '221577': 'Veľká_dolina_(rozlišovacia_stránka)',
#  '223078': 'Ján_Vesel_(rozlišovacia_stránka)',
#  '223101': 'Niagara_(rozlišovacia_stránka)',
#  '223209': 'Rozmer_(rozlišovacia_stránka)',
#  '224271': 'Myjava_(rozlišovacia_stránka)',
#  '224346': 'Kruh_(rozlišovacia_stránka)',
#  '225128': 'Srbsko_(rozlišovacia_stránka)',
#  '225365': 'Citadela_(rozlišovacia_stránka)',
#  '226396': 'Zelená_(rozlišovacia_stránka)',
#  '226398': 'Červená_(rozlišovacia_stránka)',
#  '227729': 'Mýto_(rozlišovacia_stránka)',
#  '228082': 'Vysoká_pec_(rozlišovacia_stránka)',
#  '228107': 'Killers_(rozlišovacia_stránka)',
#  '228570': 'Kuša_(rozlišovacia_stránka)',
#  '228602': 'Lučenec_(rozlišovacia_stránka)',
#  '228783': 'Incipit_(rozlišovacia_stránka)',
#  '229010': 'Providence_(rozlišovacia_stránka)',
#  '229245': 'Domobrana_(rozlišovacia_stránka)',
#  '229261': 'Kosa_(rozlišovacia_stránka)',
#  '229716': 'Jelenec_(rozlišovacia_stránka)',
#  '232642': 'Medvedie_(rozlišovacia_stránka)',
#  '232712': 'Krivá_(rozlišovacia_stránka)',
#  '233386': 'Tatry_(rozlišovacia_stránka)',
#  '234234': 'Obchvat_(rozlišovacia_stránka)',
#  '235211': 'Lima_(rozlišovacia_stránka)',
#  '235759': 'Tatran_Prešov_(rozlišovacia_stránka)',
#  '236537': 'Íl_(rozlišovacia_stránka)',
#  '237055': 'Klinec_(rozlišovacia_stránka)',
#  '237982': 'Siderit_(rozlišovacia_stránka)',
#  '238601': 'Slovensko_(rozlišovacia_stránka)',
#  '239113': 'NHL_(rozlišovacia_stránka)',
#  '240359': 'Turín_(rozlišovacia_stránka)',
#  '240524': 'Kameň_(rozlišovacia_stránka)',
#  '245048': 'King_Kong_(rozlišovacia_stránka)',
#  '245104': 'Leibnitz_(rozlišovacia_stránka)',
#  '246230': 'Mníška_(rozlišovacia_stránka)',
#  '246267': 'Mních_(rozlišovacia_stránka)',
#  '248113': 'Šport_(rozlišovacia_stránka)',
#  '248163': 'Sankt_Gallen_(rozlišovacia_stránka)',
#  '248167': 'St._Gallen_(rozlišovacia_stránka)',
#  '249229': 'Stolička_(rozlišovacia_stránka)',
#  '249569': 'Sedan_(rozlišovacia_stránka)',
#  '249613': 'Knižnica_(rozlišovacia_stránka)',
#  '250176': 'Strom_(rozlišovacia_stránka)',
#  '250707': 'Jednota_(rozlišovacia_stránka)',
#  '251277': 'Labuť_(rozlišovacia_stránka)',
#  '251321': 'Anglická_libra_(rozlišovacia_stránka)',
#  '251635': 'Kozie_mlieko_(rozlišovacia_stránka)',
#  '251977': 'Ganz_(rozlišovacia_stránka)',
#  '252038': 'Poľany_(rozlišovacia_stránka)',
#  '252292': 'Zuzana_(rozlišovacia_stránka)',
#  '252430': 'Jednota_(rozlišovacia_stránka)',
#  '252488': 'Mier_(rozlišovacia_stránka)',
#  '253309': 'Prorok_(rozlišovacia_stránka)',
#  '254865': 'Juka_(rozlišovacia_stránka)',
#  '255006': 'Ihla_(rozlišovacia_stránka)',
#  '256999': 'Súmrak_(rozlišovacia_stránka)',
#  '257129': 'Bogota_(rozlišovacia_stránka)',
#  '257528': 'Eduard_Hartmann_(rozlišovacia_stránka)',
#  '259814': 'Pena_(rozlišovacia_stránka)',
#  '259961': 'Boca_(rozlišovacia_stránka)',
#  '260917': 'Zeman_(rozlišovacia_stránka)',
#  '262043': 'Drevina_(rozlišovacia_stránka)',
#  '262675': 'Záhrada_(rozlišovacia_stránka)',
#  '263358': 'Tieň_(rozlišovacia_stránka)',
#  '263553': 'Kameň_(rozlišovacia_stránka)',
#  '270887': 'Revolúcia_(rozlišovacia_stránka)',
#  '271243': 'Medina_(rozlišovacia_stránka)',
#  '271590': 'Príroda_(rozlišovacia_stránka)',
#  '272012': 'Mlyn_(rozlišovacia_stránka)',
#  '272875': 'Vidiek_(rozlišovacia_stránka)',
#  '272962': 'Ruža_(rozlišovacia_stránka)',
#  '273351': 'Vata_(rozlišovacia_stránka)',
#  '278027': 'Komárno_(rozlišovacia_stránka)',
#  '278984': 'Ribnica_(rozlišovacia_stránka)',
#  '283372': 'Jordán_(rozlišovacia_stránka)',
#  '283523': 'Štefanovičová_(rozlišovacia_stránka)',
#  '283642': 'Würzburg_(rozlišovacia_stránka)',
#  '283852': 'Peter_Struhár_(rozlišovacia_stránka)',
#  '284165': 'Bager_(rozlišovacia_stránka)',
#  '284607': 'Milka_(rozlišovacia_stránka)',
#  '285074': 'Orange_(rozlišovacia_stránka)',
#  '285523': 'Keila_(rozlišovacia_stránka)',
#  '285688': 'Donbas_(rozlišovacia_stránka)',
#  '285728': 'Atlanta_(rozlišovacia_stránka)',
#  '286010': 'Chat_(rozlišovacia_stránka)',
#  '286913': 'Frankenstein_(rozlišovacia_stránka)',
#  '287203': 'Polícia_(rozlišovacia_stránka)',
#  '287448': 'Šestanovac_(rozlišovacia_stránka)',
#  '287978': 'Zlatňanka_(rozlišovacia_stránka)',
#  '288127': 'Pes_baskervillský_(rozlišovacia_stránka)',
#  '288702': 'Stará_Nitra_(rozlišovacia_stránka)',
#  '288754': 'Zvestovanie_(rozlišovacia_stránka)',
#  '289037': 'Mária_Terézia_(rozlišovacia_stránka)',
#  '289108': 'Exil_(rozlišovacia_stránka)',
#  '289118': 'Babylon_(rozlišovacia_stránka)',
#  '289123': 'Katapult_(rozlišovacia_stránka)',
#  '289898': 'Rastislavice_(rozlišovacia_stránka)',
#  '290782': 'Marduk_(rozlišovacia_stránka)',
#  '291119': 'Veľká_vojna_(rozlišovacia_stránka)',
#  '291300': 'Eder_(rozlišovacia_stránka)',
#  '293656': 'Vimperk_(rozlišovacia_stránka)',
#  '294115': 'Valkýra_(rozlišovacia_stránka)',
#  '295720': 'Nirvana_(rozlišovacia_stránka)',
#  '295931': 'Úsvit_(rozlišovacia_stránka)',
#  '296576': 'Kabala_(rozlišovacia_stránka)',
#  '298432': 'Hámor_(rozlišovacia_stránka)',
#  '299843': 'Android_(rozlišovacia_stránka)',
#  '299916': 'Príbeh_(rozlišovacia_stránka)',
#  '301418': 'Twist_(rozlišovacia_stránka)',
#  '301539': 'FBI_(rozlišovacia_stránka)',
#  '302471': 'Osada_(rozlišovacia_stránka)',
#  '302998': 'Drak_(rozlišovacia_stránka)',
#  '303133': 'Opel_(rozlišovacia_stránka)',
#  '303260': 'Kuchár_(rozlišovacia_stránka)',
#  '303386': 'Zatmenie_(rozlišovacia_stránka)',
#  '303489': 'Tlaková_níž_(rozlišovacia_stránka)',
#  '304051': 'Durham_(rozlišovacia_stránka)',
#  '304274': 'Zajac_(rozlišovacia_stránka)',
#  '304713': 'Arzén_(rozlišovacia_stránka)',
#  '304827': 'Horská_chata_(rozlišovacia_stránka)',
#  '305731': 'Buxus_(rozlišovacia_stránka)',
#  '308606': 'FBI_(rozlišovacia_stránka)',
#  '308803': 'Zima_(rozlišovacia_stránka)',
#  '308992': 'Čermeľ_(rozlišovacia_stránka)',
#  '309497': 'Trávnica_(rozlišovacia_stránka)',
#  '310290': 'Comeback_(rozlišovacia_stránka)',
#  '311213': 'Banská_Bystrica_(rozlišovacia_stránka)',
#  '311214': 'Prešov_(rozlišovacia_stránka)',
#  '311215': 'Košice_(rozlišovacia_stránka)',
#  '312986': 'Hermann_Schwarz_(rozlišovacia_stránka)',
#  '313009': 'Liboc_(rozlišovacia_stránka)',
#  '313012': 'Třemošná_(rozlišovacia_stránka)',
#  '313264': 'RTL_(rozlišovacia_stránka)',
#  '313648': 'Vislava_(rozlišovacia_stránka)',
#  '313656': 'Trstené_(rozlišovacia_stránka)',
#  '314686': 'Michal_Kováč_(rozlišovacia_stránka)',
#  '315946': 'Mérida_(rozlišovacia_stránka)',
#  '316475': 'Pištoľ_(rozlišovacia_stránka)',
#  '317340': 'Pomoranské_vojvodstvo_(rozlišovacia_stránka)',
#  '317876': '13_(rozlišovacia_stránka)',
#  '318154': 'R_(rozlišovacia_stránka)',
#  '319208': 'Plešivec_(rozlišovacia_stránka)',
#  '319831': 'Pláž_(rozlišovacia_stránka)',
#  '319933': 'Underground_(rozlišovacia_stránka)',
#  '322722': 'Adrian_Smith_(rozlišovacia_stránka)',
#  '323065': 'Malta_(rozlišovacia_stránka)',
#  '323125': 'Mafia_(rozlišovacia_stránka)',
#  '325200': 'Pelješac_(rozlišovacia_stránka)',
#  '327567': 'Charing_Cross_(rozlišovacia_stránka)',
#  '327800': 'Palau_(rozlišovacia_stránka)',
#  '328545': 'Apicius_(rozlišovacia_stránka)',
#  '328914': 'Kábul_(rozlišovacia_stránka)',
#  '329202': 'Manhattan_(rozlišovacia_stránka)',
#  '329404': 'Berkeley_(rozlišovacia_stránka)',
#  '331139': 'Saint-Denis_(rozlišovacia_stránka)',
#  '331707': 'Terezianum_(rozlišovacia_stránka)',
#  '332343': 'Ventilátor_(rozlišovacia_stránka)',
#  '334293': 'Hrušovo_(rozlišovacia_stránka)',
#  '336417': 'Labin_(rozlišovacia_stránka)',
#  '336860': 'Nový_zámok_(rozlišovacia_stránka)',
#  '336894': 'Krásný_Dvůr_(rozlišovacia_stránka)',
#  '337031': 'Ďurďošík_(rozlišovacia_stránka)',
#  '337193': 'Bon_Jovi_(rozlišovacia_stránka)',
#  '337787': 'Oldenburg_(rozlišovacia_stránka)',
#  '338804': 'Zrýchlenie_(rozlišovacia_stránka)',
#  '341639': 'Brod_(rozlišovacia_stránka)',
#  '342215': 'Libín_(rozlišovacia_stránka)',
#  '343744': 'Kanianka_(rozlišovacia_stránka)',
#  '344539': 'Praha_(rozlišovacia_stránka)',
#  '345907': 'Zlín_(rozlišovacia_stránka)',
#  '347296': 'Kalifornia_(rozlišovacia_stránka)',
#  '351069': 'Gladiátor_(rozlišovacia_stránka)',
#  '351071': 'Fontána_(rozlišovacia_stránka)',
#  '351072': 'Moulin_Rouge_(rozlišovacia_stránka)',
#  '351075': 'Skala_(rozlišovacia_stránka)',
#  '351076': 'Kokaín_(rozlišovacia_stránka)',
#  '351082': 'Vrana_(rozlišovacia_stránka)',
#  '351151': 'Holokaust_(rozlišovacia_stránka)',
#  '351152': 'Rím_(rozlišovacia_stránka)',
#  '352083': 'Volga_(rozlišovacia_stránka)',
#  '354244': 'Rómeo_a_Júlia_(rozlišovacia_stránka)',
#  '354428': 'Kružidlo_(rozlišovacia_stránka)',
#  '355004': 'Pella_(rozlišovacia_stránka)',
#  '356833': 'Winchester_(rozlišovacia_stránka)',
#  '359775': 'Santander_(rozlišovacia_stránka)',
#  '364007': 'Piatok_(rozlišovacia_stránka)',
#  '364124': 'Sherlock_Holmes_(rozlišovacia_stránka)',
#  '364277': 'Vred_(rozlišovacia_stránka)',
#  '364695': 'Noviny_(rozlišovacia_stránka)',
#  '364796': 'Mata_Hari_(rozlišovacia_stránka)',
#  '365278': 'Magma_(rozlišovacia_stránka)',
#  '366493': 'Lisabon_(rozlišovacia_stránka)',
#  '367151': 'Toledo_(rozlišovacia_stránka)',
#  '368129': 'Nero_(rozlišovacia_stránka)',
#  '368182': 'Freestyle_(rozlišovacia_stránka)',
#  '368444': 'Kursk_(rozlišovacia_stránka)',
#  '368863': 'Veľký_tresk_(rozlišovacia_stránka)',
#  '369316': 'Las_Vegas_(rozlišovacia_stránka)',
#  '370276': 'Admirál_(rozlišovacia_stránka)',
#  '370641': 'Ucho_(rozlišovacia_stránka)',
#  '371156': 'Michael_Richards_(rozlišovacia_stránka)',
#  '371424': 'Salisbury_(rozlišovacia_stránka)',
#  '371623': 'Lipa_(rozlišovacia_stránka)',
#  '373058': 'Orlie_pierko_(rozlišovacia_stránka)',
#  '375663': 'Damask_(rozlišovacia_stránka)',
#  '375732': 'Hebron_(rozlišovacia_stránka)',
#  '375903': '810_(rozlišovacia_stránka)',
#  '376504': 'Rum_(rozlišovacia_stránka)',
#  '376572': 'Laugaricio_(rozlišovacia_stránka)',
#  '377834': 'Esperanto_(rozlišovacia_stránka)',
#  '378105': '10_(rozlišovacia_stránka)',
#  '378106': '1_(rozlišovacia_stránka)',
#  '378108': '2_(rozlišovacia_stránka)',
#  '378109': '3_(rozlišovacia_stránka)',
#  '378110': '4_(rozlišovacia_stránka)',
#  '378111': '5_(rozlišovacia_stránka)',
#  '378112': '6_(rozlišovacia_stránka)',
#  '378113': '7_(rozlišovacia_stránka)',
#  '378114': '8_(rozlišovacia_stránka)',
#  '378115': '9_(rozlišovacia_stránka)',
#  '379587': 'Veľká_vlastenecká_vojna_(rozlišovacia_stránka)',
#  '379637': 'Tau_(rozlišovacia_stránka)',
#  '380382': 'Orchomenos_(rozlišovacia_stránka)',
#  '380947': 'Žďárek_(rozlišovacia_stránka)',
#  '383322': 'Hippodameia_(rozlišovacia_stránka)',
#  '383728': 'Babia_hora_(rozlišovacia_stránka)',
#  '384580': 'Peisistratos_(rozlišovacia_stránka)',
#  '385072': 'Gorila_(rozlišovacia_stránka)',
#  '385384': 'Boreas_(rozlišovacia_stránka)',
#  '385669': 'Nový_Zámok_(rozlišovacia_stránka)',
#  '386059': 'Drevo_(rozlišovacia_stránka)',
#  '389129': 'Čierna_Hora_(rozlišovacia_stránka)',
#  '389166': 'Krosná_(rozlišovacia_stránka)',
#  '389741': 'Buchlov_(rozlišovacia_stránka)',
#  '392468': 'Magnet_(rozlišovacia_stránka)',
#  '434710': 'Vaucluse_(rozlišovacia_stránka)',
#  '435903': 'Čad_(rozlišovacia_stránka)',
#  '436156': 'Šakal_(rozlišovacia_stránka)',
#  '436608': 'Fonograf_(rozlišovacia_stránka)',
#  '438841': 'Camembert_(rozlišovacia_stránka)',
#  '439688': 'Trojuholník_(rozlišovacia_stránka)',
#  '441727': 'Databáza_(rozlišovacia_stránka)',
#  '442370': 'Žleby_(rozlišovacia_stránka)',
#  '443664': 'Žižkov_(rozlišovacia_stránka)',
#  '446583': 'Skicár_(rozlišovacia_stránka)',
#  '446630': 'Hosta_(rozlišovacia_stránka)',
#  '446787': 'Vidlička_(rozlišovacia_stránka)',
#  '447209': '350_(rozlišovacia_stránka)',
#  '447211': '813_(rozlišovacia_stránka)',
#  '448126': '2012_(rozlišovacia_stránka)',
#  '448127': 'Gulliverove_cesty_(rozlišovacia_stránka)',
#  '448468': 'Znásilnenie_(rozlišovacia_stránka)',
#  '452458': 'Buffalo_Bill_(rozlišovacia_stránka)',
#  '452890': 'Salza_(rozlišovacia_stránka)',
#  '452891': 'Steyr_(rozlišovacia_stránka)',
#  '452894': 'Traun_(rozlišovacia_stránka)',
#  '453124': 'Traja_mušketieri_(rozlišovacia_stránka)',
#  '453651': 'Káthmandu_(rozlišovacia_stránka)',
#  '453671': 'Spevák_(rozlišovacia_stránka)',
#  '453987': 'Slovenský_rozhlas_(rozlišovacia_stránka)',
#  '459884': 'Thestios_(rozlišovacia_stránka)',
#  '459908': 'Sudán_(rozlišovacia_stránka)',
#  '461420': 'Strymón_(rozlišovacia_stránka)',
#  '463192': 'Miková_(rozlišovacia_stránka)',
#  '463237': 'TV_Nova_(rozlišovacia_stránka)',
#  '463656': 'Bedári_(rozlišovacia_stránka)',
#  '463786': 'Miltiades_(rozlišovacia_stránka)',
#  '463846': 'Génius_(rozlišovacia_stránka)',
#  '464425': 'Faistos_(rozlišovacia_stránka)',
#  '464939': 'New_Orleans_(rozlišovacia_stránka)',
#  '465180': 'Karlštejn_(rozlišovacia_stránka)',
#  '465768': '300_(rozlišovacia_stránka)',
#  '466307': 'Amsterdam_(rozlišovacia_stránka)',
#  '466309': 'Aischylos_(rozlišovacia_stránka)',
#  '473929': 'Veľké_Pole_(rozlišovacia_stránka)',
#  '474635': 'Anjel_(rozlišovacia_stránka)',
#  '475128': 'Komunizmus_(rozlišovacia_stránka)',
#  '475460': 'Rakúsko_(rozlišovacia_stránka)',
#  '475807': 'Emil_Horváth_(rozlišovacia_stránka)',
#  '475934': 'Les_(rozlišovacia_stránka)',
#  '478394': 'Turčok_(rozlišovacia_stránka)',
#  '480429': 'John_Williams_(rozlišovacia_stránka)',
#  '480869': 'Sahara_(rozlišovacia_stránka)',
#  '481063': 'Jan_Fischer_(rozlišovacia_stránka)',
#  '481459': 'Auros_(rozlišovacia_stránka)',
#  '481462': 'Bazas_(rozlišovacia_stránka)',
#  '481472': 'Cadillac_(rozlišovacia_stránka)',
#  '481487': 'Andolsheim_(rozlišovacia_stránka)',
#  '481763': 'Ska_(rozlišovacia_stránka)',
#  '481843': 'Traktor_(rozlišovacia_stránka)',
#  '482034': 'Sirota_(rozlišovacia_stránka)',
#  '482053': 'Vdova_(rozlišovacia_stránka)',
#  '482055': 'Láska_(rozlišovacia_stránka)',
#  '482058': 'Ponorka_(rozlišovacia_stránka)',
#  '482074': 'Byt_(rozlišovacia_stránka)',
#  '482075': 'Amatér_(rozlišovacia_stránka)',
#  '482077': 'Profesionál_(rozlišovacia_stránka)',
#  '482078': 'Zlo_(rozlišovacia_stránka)',
#  '482158': 'Prízrak_(rozlišovacia_stránka)',
#  '482218': 'Vír_(rozlišovacia_stránka)',
#  '482272': 'Lano_(rozlišovacia_stránka)',
#  '482618': 'Albertville_(rozlišovacia_stránka)',
#  '482621': 'Jozef_Škultéty_(rozlišovacia_stránka)',
#  '482818': 'Borgiovci_(rozlišovacia_stránka)',
#  '482820': 'Pápež_(rozlišovacia_stránka)',
#  '483408': 'Kohen_(rozlišovacia_stránka)',
#  '483572': 'Alcatraz_(rozlišovacia_stránka)',
#  '483882': 'Zvon_(rozlišovacia_stránka)',
#  '484385': 'Mór_(rozlišovacia_stránka)',
#  '484553': 'Krajčír_(rozlišovacia_stránka)',
#  '484814': 'Jana_Eyrová_(rozlišovacia_stránka)',
#  '485926': 'Šoltýs_(rozlišovacia_stránka)',
#  '489465': 'Vodárenská_veža_(rozlišovacia_stránka)',
#  '492138': 'Lietadlo_(rozlišovacia_stránka)',
#  '493146': 'Modra_(rozlišovacia_stránka)',
#  '493168': 'Kobra_(rozlišovacia_stránka)',
#  '493214': 'Dekýš_(rozlišovacia_stránka)',
#  '494099': 'Politika_(rozlišovacia_stránka)',
#  '494509': 'Kuba_(rozlišovacia_stránka)',
#  '495299': 'Litva_(rozlišovacia_stránka)',
#  '495354': 'Sibír_(rozlišovacia_stránka)',
#  '495751': 'Otčenáš_(rozlišovacia_stránka)',
#  '495758': 'Štrba_(rozlišovacia_stránka)',
#  '495773': 'Husár_(rozlišovacia_stránka)',
#  '495999': 'Plešina_(rozlišovacia_stránka)',
#  '496096': 'Sekera_(rozlišovacia_stránka)',
#  '496192': 'Rosina_(rozlišovacia_stránka)',
#  '496228': 'Rosa_(rozlišovacia_stránka)',
#  '496243': 'Richtár_(rozlišovacia_stránka)',
#  '496303': 'Janík_(rozlišovacia_stránka)',
#  '496401': 'Dusík_(rozlišovacia_stránka)',
#  '496848': 'Puška_(rozlišovacia_stránka)',
#  '497200': 'Jiří_Vaněk_(rozlišovacia_stránka)',
#  '497780': 'Columbo_(rozlišovacia_stránka)',
#  '497837': 'Michalková_(rozlišovacia_stránka)',
#  '498343': 'Čokoláda_(rozlišovacia_stránka)',
#  '498918': 'Ilija_(rozlišovacia_stránka)',
#  '498964': 'Bologna_(rozlišovacia_stránka)',
#  '499580': 'Loj_(rozlišovacia_stránka)',
#  '500024': 'Nóri_(rozlišovacia_stránka)',
#  '500058': '69_(rozlišovacia_stránka)',
#  '500278': 'Tehelňa_(rozlišovacia_stránka)',
#  '500282': 'Tehelňa_(rozlišovacia_stránka)',
#  '500490': 'Próteus_(rozlišovacia_stránka)',
#  '500628': 'Bousiris_(rozlišovacia_stránka)',
#  '500909': 'Jiří_Rusnok_(rozlišovacia_stránka)',
#  '501016': 'Alexander_Veľký_(rozlišovacia_stránka)',
#  '501116': 'Záruby_(rozlišovacia_stránka)',
#  '501155': 'Aneroid_(rozlišovacia_stránka)',
#  '501453': 'Richmond_(rozlišovacia_stránka)',
#  '501578': 'Peterborough_(rozlišovacia_stránka)',
#  '501626': '42_(rozlišovacia_stránka)',
#  '501756': 'Kremnička_(rozlišovacia_stránka)',
#  '501798': 'Jelka_(rozlišovacia_stránka)',
#  '502506': 'Nový_Svet_(rozlišovacia_stránka)',
#  '502690': 'Memfis_(rozlišovacia_stránka)',
#  '502895': 'Long_Beach_(rozlišovacia_stránka)',
#  '503088': 'Augé_(rozlišovacia_stránka)',
#  '503197': 'Texas_(rozlišovacia_stránka)',
#  '504069': 'Idmón_(rozlišovacia_stránka)',
#  '504449': 'Oinóné_(rozlišovacia_stránka)',
#  '504716': 'Pylos_(rozlišovacia_stránka)',
#  '505534': 'Síra_(rozlišovacia_stránka)',
#  '505652': 'Alkes_(rozlišovacia_stránka)',
#  '506991': 'Agrón_(rozlišovacia_stránka)',
#  '507534': 'Miroslav_(rozlišovacia_stránka)',
#  '507876': 'Brusel_(rozlišovacia_stránka)',
#  '507907': 'Brusel_(rozlišovacia_stránka)',
#  '508092': 'Askanios_(rozlišovacia_stránka)',
#  '508222': 'Magnólia_(rozlišovacia_stránka)',
#  '508225': 'Koktail_(rozlišovacia_stránka)',
#  '508762': 'La_Rochelle_(rozlišovacia_stránka)',
#  '510810': 'Idea_(rozlišovacia_stránka)',
#  '512761': 'Aulos_(rozlišovacia_stránka)',
#  '513302': 'Pisa_(rozlišovacia_stránka)',
#  '513941': 'Démosthenes_(rozlišovacia_stránka)',
#  '513942': 'Demostenes_(rozlišovacia_stránka)',
#  '515023': 'Epidauros_(rozlišovacia_stránka)',
#  '517463': 'Kaliningrad_(rozlišovacia_stránka)',
#  '518007': 'Počítač_(rozlišovacia_stránka)',
#  '519255': 'Beňuš_(rozlišovacia_stránka)',
#  '519479': 'Carlos_Pellegrini_(rozlišovacia_stránka)',
#  '519530': 'Slobodník_(rozlišovacia_stránka)',
#  '519813': 'Rozkoš_(rozlišovacia_stránka)',
#  '520224': 'Magnes_(rozlišovacia_stránka)',
#  '521166': 'Leto_(rozlišovacia_stránka)',
#  '521184': 'Togo_(rozlišovacia_stránka)',
#  '521879': 'Bán_(rozlišovacia_stránka)',
#  '521882': 'Bánová_(rozlišovacia_stránka)',
#  '521928': 'Clichy_(rozlišovacia_stránka)',
#  '522077': 'Ker_(rozlišovacia_stránka)',
#  '523108': 'Megara_(rozlišovacia_stránka)',
#  '523332': 'Bobuľa_(rozlišovacia_stránka)',
#  '524405': 'Wake_(rozlišovacia_stránka)',
#  '524765': 'Nota_(rozlišovacia_stránka)',
#  '526137': 'Catania_(rozlišovacia_stránka)',
#  '527507': 'Zábřeh_(rozlišovacia_stránka)',
#  '527531': '38_(rozlišovacia_stránka)',
#  '528903': 'Ostreľovač_(rozlišovacia_stránka)',
#  '529308': 'Čechy_pod_Kosířem_(rozlišovacia_stránka)',
#  '529441': 'Park_(rozlišovacia_stránka)',
#  '529443': 'Park_(rozlišovacia_stránka)',
#  '529703': 'Lopata_(rozlišovacia_stránka)',
#  '530268': 'Vojak_(rozlišovacia_stránka)',
#  '530269': 'Vojak_(rozlišovacia_stránka)',
#  '530696': 'Bezpečnosť_(rozlišovacia_stránka)',
#  '531920': 'Revolver_(rozlišovacia_stránka)',
#  '532717': 'Hermogenes_(rozlišovacia_stránka)',
#  '532969': 'Muži_v_čiernom_(rozlišovacia_stránka)',
#  '533154': 'Lietadlo_(rozlišovacia_stránka)',
#  '533286': 'Mechanik_(rozlišovacia_stránka)',
#  '534391': 'Prezident_(rozlišovacia_stránka)',
#  '534642': 'Daidalos_(rozlišovacia_stránka)',
#  '534676': 'Minerva_(rozlišovacia_stránka)',
#  '534740': 'Atacama_(rozlišovacia_stránka)',
#  '535197': 'Homér_(rozlišovacia_stránka)',
#  '535662': 'Saint-Tropez_(rozlišovacia_stránka)',
#  '541738': 'Oltár_(rozlišovacia_stránka)',
#  '541741': 'Javisko_(rozlišovacia_stránka)',
#  '542259': 'Ostreľovač_(rozlišovacia_stránka)',
#  '542523': 'Télemachos_(rozlišovacia_stránka)',
#  '542732': 'Zdravie_(rozlišovacia_stránka)',
#  '542733': 'Jantár_(rozlišovacia_stránka)',
#  '542743': 'Periskop_(rozlišovacia_stránka)',
#  '542812': 'Fotograf_(rozlišovacia_stránka)',
#  '543003': 'Vybíjaná_(rozlišovacia_stránka)',
#  '543132': 'Xenofón_(rozlišovacia_stránka)',
#  '547030': 'Osádka_(rozlišovacia_stránka)',
#  '547070': 'Pruské_kráľovstvo_(rozlišovacia_stránka)',
#  '547332': 'Človek_rozumný_(rozlišovacia_stránka)',
#  '547439': 'Slovensko_(rozlišovacia_stránka)',
#  '549137': 'Prokles_(rozlišovacia_stránka)',
#  '550181': 'Hérodotos_(rozlišovacia_stránka)',
#  '550248': 'Lysippos_(rozlišovacia_stránka)',
#  '550656': 'Kostolište_(rozlišovacia_stránka)',
#  '550659': 'Lehôtka_(rozlišovacia_stránka)',
#  '550885': 'Polyneikes_(rozlišovacia_stránka)',
#  '552348': 'Líbya_(rozlišovacia_stránka)',
#  '552499': 'Vulcano_(rozlišovacia_stránka)',
#  '553563': 'Krypta_(rozlišovacia_stránka)',
#  '553582': 'Xenón_(rozlišovacia_stránka)',
#  '554691': 'Kranaos_(rozlišovacia_stránka)',
#  '555298': 'Kleitomachos_(rozlišovacia_stránka)',
#  '555378': 'Menestheus_(rozlišovacia_stránka)',
#  '555644': 'Polyméstor_(rozlišovacia_stránka)',
#  '556093': 'Marco_Polo_(rozlišovacia_stránka)',
#  '556222': 'Čierne_(rozlišovacia_stránka)',
#  '556269': 'Írska_republikánska_armáda_(rozlišovacia_stránka)',
#  '557323': 'Waterford_(rozlišovacia_stránka)',
#  '559171': 'Thomas_Mann_(rozlišovacia_stránka)',
#  '559625': 'Blesk_(rozlišovacia_stránka)',
#  '560415': 'Strach_(rozlišovacia_stránka)',
#  '560426': 'Althaimenes_(rozlišovacia_stránka)',
#  '560661': 'West_Ham_(rozlišovacia_stránka)',
#  '560699': 'Pompeje_(rozlišovacia_stránka)',
#  '560987': 'Reading_(rozlišovacia_stránka)',
#  '561828': 'Astyanax_(rozlišovacia_stránka)',
#  '561855': 'Pavol_Rusko_(rozlišovacia_stránka)',
#  '562251': 'Edinburgh_(rozlišovacia_stránka)',
#  '562731': 'Izba_(rozlišovacia_stránka)',
#  '562933': 'Almanach_(rozlišovacia_stránka)',
#  '563360': 'Tamburína_(rozlišovacia_stránka)',
#  '563918': 'Hainburg_(rozlišovacia_stránka)',
#  '564523': 'Stránky_na_zmazanie/Slobodný_vysielač_(rozlišovacia_stránka)',
#  '564682': 'Aristofanes_(rozlišovacia_stránka)',
#  '565828': 'Fakulta_(rozlišovacia_stránka)',
#  '565838': 'Zelené_pleso_(rozlišovacia_stránka)',
#  '565883': 'Ilúzia_(rozlišovacia_stránka)',
#  '566657': 'Tróilos_(rozlišovacia_stránka)',
#  '567128': 'Lomné_(rozlišovacia_stránka)',
#  '567635': 'Letisko_(rozlišovacia_stránka)',
#  '567724': 'Brooklyn_(rozlišovacia_stránka)',
#  '567943': 'Trója_(rozlišovacia_stránka)',
#  '570119': 'Surovina_(rozlišovacia_stránka)',
#  '571035': 'Basarabeasca_(rozlišovacia_stránka)',
#  '571385': 'Dišputa_(rozlišovacia_stránka)',
#  '572328': 'Empedokles_(rozlišovacia_stránka)',
#  '572747': 'Donovan_(rozlišovacia_stránka)',
#  '572974': 'Motyka_(rozlišovacia_stránka)',
#  '573743': 'Černík_(rozlišovacia_stránka)',
#  '574415': 'Ithaka_(rozlišovacia_stránka)',
#  '574422': 'Žarnovica_(rozlišovacia_stránka)',
#  '574549': 'Bán_(rozlišovacia_stránka)',
#  '574617': 'Dopisovateľ_(rozlišovacia_stránka)',
#  '574646': 'Baňa_(rozlišovacia_stránka)',
#  '575691': 'Árpás_(rozlišovacia_stránka)',
#  '575900': 'Kaharlyk_(rozlišovacia_stránka)',
#  '577636': 'Kocka_(rozlišovacia_stránka)',
#  '577779': 'Tupá_(rozlišovacia_stránka)',
#  '577848': 'Omáčka_(rozlišovacia_stránka)',
#  '578047': 'Bora_Bora_(rozlišovacia_stránka)',
#  '578059': 'Bór_(rozlišovacia_stránka)',
#  '578106': 'Borka_(rozlišovacia_stránka)',
#  '578407': 'YMCA_(rozlišovacia_stránka)',
#  '578420': 'Arťomovskij_(rozlišovacia_stránka)',
#  '578732': 'Démaratos_(rozlišovacia_stránka)',
#  '578840': 'Nysa_(rozlišovacia_stránka)',
#  '579294': 'Mšeno_(rozlišovacia_stránka)',
#  '579770': 'Veltrusy_(rozlišovacia_stránka)',
#  '580782': 'Žatec_(rozlišovacia_stránka)',
#  '581204': 'Číčov_(rozlišovacia_stránka)',
#  '581301': 'Prognóza_(rozlišovacia_stránka)',
#  '582181': 'Jeseter_(rozlišovacia_stránka)',
#  '583017': 'Václav_Havel_(rozlišovacia_stránka)',
#  '584082': 'Reflex_(rozlišovacia_stránka)',
#  '584196': 'Kráľ_Artuš_(rozlišovacia_stránka)',
#  '584883': 'Hmla_(rozlišovacia_stránka)',
#  '585262': 'Studňa_(rozlišovacia_stránka)',
#  '585475': 'Rúbaň_(rozlišovacia_stránka)',
#  '587444': 'Machy_(rozlišovacia_stránka)',
#  '587685': 'Stuttgart_(rozlišovacia_stránka)',
#  '590707': 'Nedeľa_(rozlišovacia_stránka)',
#  '591964': '1890_(rozlišovacia_stránka)',
#  '591974': 'Starosta_(rozlišovacia_stránka)',
#  '592292': 'Eucharistia_(rozlišovacia_stránka)',
#  '592972': 'Elektrón_(rozlišovacia_stránka)',
#  '592988': 'Kydón_(rozlišovacia_stránka)',
#  '596454': 'Hanková_(rozlišovacia_stránka)',
#  '597639': 'Ulica_(rozlišovacia_stránka)',
#  '598277': 'Boh_(rozlišovacia_stránka)',
#  '598486': 'Rozhovor_(rozlišovacia_stránka)',
#  '598563': 'Lysica_(rozlišovacia_stránka)',
#  '599068': 'Karma_(rozlišovacia_stránka)',
#  '599074': 'Sókrates_(rozlišovacia_stránka)',
#  '599601': 'Atlantída_(rozlišovacia_stránka)',
#  '599701': 'Dunaj_(rozlišovacia_stránka)',
#  '600126': 'Ropice_(rozlišovacia_stránka)',
#  '600131': 'Gréci_(rozlišovacia_stránka)',
#  '600201': 'Orient_(rozlišovacia_stránka)',
#  '600595': 'Triglav_(rozlišovacia_stránka)',
#  '601610': '112_(rozlišovacia_stránka)',
#  '602193': 'Kandidát_(rozlišovacia_stránka)',
#  '605775': 'Gubernia_(rozlišovacia_stránka)',
#  '607039': 'Taška_(rozlišovacia_stránka)',
#  '607597': 'Zemný_plyn_(rozlišovacia_stránka)',
#  '607603': 'Zemný_plyn_(rozlišovacia_stránka)',
#  '608130': 'Karkúk_(rozlišovacia_stránka)',
#  '609390': 'Lovča_(rozlišovacia_stránka)',
#  '609392': 'Stéla_(rozlišovacia_stránka)',
#  '609904': 'Flauta_(rozlišovacia_stránka)',
#  '610530': 'Čiara_(rozlišovacia_stránka)',
#  '610842': 'Blatné_(rozlišovacia_stránka)',
#  '611139': 'Corpus_delicti_(rozlišovacia_stránka)',
#  '611504': 'Prst_(rozlišovacia_stránka)',
#  '611768': 'Mamut_(rozlišovacia_stránka)',
#  '611784': 'Norok_(rozlišovacia_stránka)',
#  '612477': 'Tiaž_(rozlišovacia_stránka)',
#  '612639': 'Kritias_(rozlišovacia_stránka)',
#  '614669': 'Antiochia_(rozlišovacia_stránka)',
#  '615384': 'Krymská_republika_(rozlišovacia_stránka)',
#  '615772': 'Prekambrium_(rozlišovacia_stránka)',
#  '615785': 'Proterozoikum_(rozlišovacia_stránka)',
#  '615792': 'Paleozoikum_(rozlišovacia_stránka)',
#  '615793': 'Prvohory_(rozlišovacia_stránka)',
#  '615795': 'Terciér_(rozlišovacia_stránka)',
#  '615797': 'Kenozoikum_(rozlišovacia_stránka)',
#  '615809': 'Archaikum_(rozlišovacia_stránka)',
#  '615838': 'Druhohory_(rozlišovacia_stránka)',
#  '615841': 'Treťohory_(rozlišovacia_stránka)',
#  '616309': 'Anexia_(rozlišovacia_stránka)',
#  '616320': 'Pilot_(rozlišovacia_stránka)',
#  '616782': 'Hmyz_(rozlišovacia_stránka)',
#  '617010': 'Juraj_Štefanka_(rozlišovacia_stránka)',
#  '617406': 'Vega_(rozlišovacia_stránka)',
#  '617577': 'Phobetor_(rozlišovacia_stránka)',
#  '617579': 'Poltergeist_(rozlišovacia_stránka)',
#  '617794': 'Družica_(rozlišovacia_stránka)',
#  '618055': 'Zástava_(rozlišovacia_stránka)',
#  '618853': 'Sekunda_(rozlišovacia_stránka)',
#  '618857': 'Minúta_(rozlišovacia_stránka)',
#  '619283': 'Jednorožec_(rozlišovacia_stránka)',
#  '619440': 'Helvetios_(rozlišovacia_stránka)',
#  '620144': 'Čechoslovakizmus_(rozlišovacia_stránka)',
#  '620877': 'Remeslo_(rozlišovacia_stránka)',
#  '620878': 'Cech_(rozlišovacia_stránka)',
#  '621022': 'Tomáš_Gábriš_(rozlišovacia_stránka)',
#  '622026': 'Hron_(rozlišovacia_stránka)',
#  '622710': 'Pruština_(rozlišovacia_stránka)',
#  '623680': 'Prestup_tepla_(rozlišovacia_stránka)',
#  '623727': 'Volbeat_(rozlišovacia_stránka)',
#  '623941': 'Sendvič_(rozlišovacia_stránka)',
#  '624148': 'Héfaistión_(rozlišovacia_stránka)',
#  '624414': 'Asklépios_(rozlišovacia_stránka)',
#  '624748': 'B2_(rozlišovacia_stránka)',
#  '624886': 'Orangutan_(rozlišovacia_stránka)',
#  '625310': 'Nemea_(rozlišovacia_stránka)',
#  '625644': 'Pieseň_(rozlišovacia_stránka)',
#  '626469': 'Doc_Holliday_(rozlišovacia_stránka)',
#  '626577': 'Lola_Montez_(rozlišovacia_stránka)',
#  '627316': 'Docent_(rozlišovacia_stránka)',
#  '627882': 'Slováci_(rozlišovacia_stránka)',
#  '628156': 'Kinematografia_(rozlišovacia_stránka)',
#  '628162': 'Kinematografia_(rozlišovacia_stránka)',
#  '628613': 'Náradie_(rozlišovacia_stránka)',
#  '628828': 'Dust_Bowl_(rozlišovacia_stránka)',
#  '629745': 'Kráľova_hoľa_(rozlišovacia_stránka)',
#  '629751': 'Bohemian_Rhapsody_(rozlišovacia_stránka)',
#  '629806': 'Internát_(rozlišovacia_stránka)',
#  '629877': 'Madonna_(rozlišovacia_stránka)',
#  '630607': 'Vichren_(rozlišovacia_stránka)',
#  '631580': '11_(rozlišovacia_stránka)',
#  '631581': '12_(rozlišovacia_stránka)',
#  '631582': '14_(rozlišovacia_stránka)',
#  '631583': '15_(rozlišovacia_stránka)',
#  '631584': '17_(rozlišovacia_stránka)',
#  '631860': 'Danko_Jones_(rozlišovacia_stránka)',
#  '631897': 'Kali_(rozlišovacia_stránka)',
#  '632840': 'Krídlovka_(rozlišovacia_stránka)',
#  '633006': 'Nové_pole_(rozlišovacia_stránka)',
#  '633028': 'Južné_mesto_(rozlišovacia_stránka)',
#  '633052': 'Pečeň_(rozlišovacia_stránka)',
#  '633399': 'Starý_háj_(rozlišovacia_stránka)',
#  '633543': 'Nos_(rozlišovacia_stránka)',
#  '633544': 'Dvorník_(rozlišovacia_stránka)',
#  '633556': 'Holica_(rozlišovacia_stránka)',
#  '633704': 'Topenie_(rozlišovacia_stránka)',
#  '633759': 'Príživníctvo_(rozlišovacia_stránka)',
#  '633991': 'Lokša_(rozlišovacia_stránka)',
#  '634042': 'Senior_(rozlišovacia_stránka)',
#  '634061': 'Tetovanie_(rozlišovacia_stránka)',
#  '634234': 'Černobyľ_(rozlišovacia_stránka)',
#  '634262': 'Černobyľ_(rozlišovacia_stránka)',
#  '634408': 'Česko_(rozlišovacia_stránka)',
#  '634730': 'Prsteň_(rozlišovacia_stránka)',
#  '634742': 'Klobúk_(rozlišovacia_stránka)',
#  '634770': 'Čiernohorci_(rozlišovacia_stránka)',
#  '634777': 'Čiernohorci_(rozlišovacia_stránka)',
#  '635091': 'Pneumatika_(rozlišovacia_stránka)',
#  '636445': 'Danzig_(rozlišovacia_stránka)',
#  '636629': 'Heracles_(rozlišovacia_stránka)',
#  '636848': 'Monoskop_(rozlišovacia_stránka)',
#  '637035': 'Nálevníky_(rozlišovacia_stránka)',
#  '637355': 'Bábovka_(rozlišovacia_stránka)',
#  '637380': 'Caggiano_(rozlišovacia_stránka)',
#  '637493': 'Diplomacia_(rozlišovacia_stránka)',
#  '637602': 'Vinič_(rozlišovacia_stránka)',
#  '637611': 'Hrozno_(rozlišovacia_stránka)',
#  '638638': 'Práčka_(rozlišovacia_stránka)',
#  '638941': 'Banán_(rozlišovacia_stránka)',
#  '640687': 'Krvavá_pani_(rozlišovacia_stránka)',
#  '640786': 'Izrael_(rozlišovacia_stránka)',
#  '640813': 'Kaprál_(rozlišovacia_stránka)',
#  '641554': 'Srbské_kráľovstvo_(rozlišovacia_stránka)',
#  '642270': 'Zebra_(rozlišovacia_stránka)',
#  '642343': 'Kána_(rozlišovacia_stránka)',
#  '642675': 'Ambulancia_(rozlišovacia_stránka)',
#  '643176': 'Aalen_(rozlišovacia_stránka)',
#  '643185': 'Para_(rozlišovacia_stránka)',
#  '643634': 'Alibi_(rozlišovacia_stránka)',
#  '643694': 'Očnica_(rozlišovacia_stránka)',
#  '647669': 'Anatómia_(rozlišovacia_stránka)',
#  '648149': 'Váh_(rozlišovacia_stránka)',
#  '648158': 'Sümeg_(rozlišovacia_stránka)',
#  '648175': 'Bodrog_(rozlišovacia_stránka)',
#  '648371': 'Šopron_(rozlišovacia_stránka)',
#  '648565': 'Medicína_(rozlišovacia_stránka)',
#  '650517': 'Sic_(rozlišovacia_stránka)',
#  '650860': 'Jazero_(rozlišovacia_stránka)',
#  '651498': 'Sklovina_(rozlišovacia_stránka)',
#  '651587': 'Elam_(rozlišovacia_stránka)',
#  '651636': 'Aššur_(rozlišovacia_stránka)',
#  '651953': 'E-mail_(rozlišovacia_stránka)',
#  '652157': 'Sverepec_(rozlišovacia_stránka)',
#  '652834': 'Hermafrodit_(rozlišovacia_stránka)',
#  '652836': 'Bisexualita_(rozlišovacia_stránka)',
#  '652864': 'Prašník_(rozlišovacia_stránka)',
#  '652956': 'Hexabiblos_(rozlišovacia_stránka)',
#  '653307': 'Minerál_(rozlišovacia_stránka)',
#  '653742': 'Enrico_Dandolo_(rozlišovacia_stránka)',
#  '653797': 'Archón_(rozlišovacia_stránka)',
#  '654550': 'Richman_(rozlišovacia_stránka)',
#  '654671': 'Danov_chălm_(rozlišovacia_stránka)',
#  '654772': 'Karl_Marx_(rozlišovacia_stránka)',
#  '654989': 'Životný_cyklus_(rozlišovacia_stránka)',
#  '655309': 'Vígľaš_(rozlišovacia_stránka)',
#  '655318': 'Vršatec_(rozlišovacia_stránka)',
#  '655320': 'Topoľčany_(rozlišovacia_stránka)',
#  '655324': 'Holíč_(rozlišovacia_stránka)',
#  '655341': 'Trebišov_(rozlišovacia_stránka)',
#  '655346': 'Michalovce_(rozlišovacia_stránka)',
#  '655347': 'Hlohovec_(rozlišovacia_stránka)',
#  '655387': 'Sokoľ_(rozlišovacia_stránka)',
#  '655389': 'Kežmarok_(rozlišovacia_stránka)',
#  '655396': 'Gelnica_(rozlišovacia_stránka)',
#  '655407': 'Tvrdošín_(rozlišovacia_stránka)',
#  '655408': 'Bytča_(rozlišovacia_stránka)',
#  '655416': 'Salzburg_(rozlišovacia_stránka)'}

# %% [markdown]
# ### Streamove parsovanie skwiki-latest-pages-articles.xml

# %%
import xml.sax
import csv

class PageHandler(xml.sax.ContentHandler):
    def __init__(self):
        self.LINE_REGEX = "\*.*"
        self.URL_REGEX = "\[\[(.*)\]\]"
        self.DESC_REGEX = ""
        
        self.FILE_NAME = "vinf_export.csv"
        self.ID = "id"
        self.TEXT = "text"
        self.TITLE = "title"
        
        self.buffer = {}
        self.current_tag = ""
        self.in_page = False
        self.in_revision = False
        
        self.file = open(self.FILE_NAME, 'w', encoding="utf-8")
        self.writer = csv.writer(self.file)
        
    def parseDisambiguationText(self):
        return re.findall(self.LINE_REGEX, self.buffer[self.TEXT])
    
    def parseUrl(self, line):
        url = re.findall(self.URL_REGEX, line)
        if url:
            url = url[0].split("'")[1] if "'" in url[0] else url[0]
            url = url.split("|")[0] if "|" in url else url
            url = "sk.wikipedia.org/wiki/" + url
            url = url.replace(" ", "_")
        return url
    
        
    def parseDisambiguationPage(self):
        desc_lines = self.parseDisambiguationText()
        urls = [self.parseUrl(line) for line in desc_lines]
        
        desc_with_url = [x for xs in zip(desc_lines, urls) for x in xs]
        
        row = [
            self.buffer[self.ID],
            self.buffer[self.TITLE],
            *desc_with_url
        ]
        
        self.writer.writerow(row)
    
    def startElement(self, tag, attributes):
        self.current_tag = tag
        if "page" in tag:
            self.in_page = True
        if "revision" in tag:
            self.in_revision = True

    def endElement(self, tag):
        if "revision" in tag:
            self.in_revision = False
            
        if "page" in tag:
            self.in_page = False
            if self.buffer[self.ID] in disambiguation_pages:
                self.parseDisambiguationPage()
            self.buffer = {}
            
        self.current_tag = ""

    def characters(self, content):
        # ID stranky
        if self.ID in self.current_tag and not self.in_revision:
            if self.ID in self.buffer:
                        self.buffer[self.ID] = self.buffer[self.ID].join(content)
            else:
                self.buffer[self.ID] = "".join(content)
        
        # Nazov stranky
        if self.TITLE in self.current_tag:
            if self.TITLE in self.buffer:
                        self.buffer[self.TITLE] = self.buffer[self.TITLE].join(content)
            else:
                self.buffer[self.TITLE] = "".join(content)
        
        # Text stranky
        if self.TEXT in self.current_tag:
            if self.TEXT in self.buffer:
                        self.buffer[self.TEXT] += content
            else:
                self.buffer[self.TEXT] = content
        
    def endDocument(self):
        if self.file:
            self.file.close()
                
parser = xml.sax.make_parser()
# turn off namespaces
parser.setFeature(xml.sax.handler.feature_namespaces, 0)
parser.setContentHandler( PageHandler() )

parser.parse("skwiki-latest-pages-articles.xml")

# %%
pip install whoosh
# Out:
# Collecting whoosh
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
# Installing collected packages: whoosh
# Successfully installed whoosh-2.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from whoosh.index import *
from whoosh.fields import *
from whoosh.analysis import *
from whoosh.support.charset import accent_map
import os
# schema = Schema(title=TEXT(stored=True), path=ID(stored=True), content=TEXT)
# ix = create_in("indexdir", schema)
# writer = ix.writer()
# writer.add_document(title=u"First document", path=u"/a",
#                      content=u"This is the first document we've added!")
# writer.add_document(title=u"Second document", path=u"/b",
#                      content=u"The second one is even more interesting!")
# writer.commit()
# from whoosh.qparser import QueryParser
# with ix.searcher() as searcher:
#     query = QueryParser("content", ix.schema).parse("first")
#     results = searcher.search(query)
#     results[0]

# %%
schema = Schema(content=TEXT(stored=True, analyzer=RegexTokenizer() | LowercaseFilter() | CharsetFilter(accent_map)))

if not os.path.exists("index"):
    os.mkdir("index")
ix = create_in("index", schema)

ix = open_dir("index")

writer = ix.writer()

with open("vinf_export.csv", 'r', encoding='utf-8') as file:
    for line in file:
        writer.add_document(content=line)

writer.commit()

# %%
from whoosh.qparser import QueryParser

qp = QueryParser("content", schema=ix.schema)
q = qp.parse(u"film")

with ix.searcher() as s:
    results = s.search(q)
    for res in results:
        print(res)
        print('\n')
# Out:
# <Hit {'content': '286913,Frankenstein (rozlišovacia stránka),* román [[Frankenstein]],sk.wikipedia.org/wiki/Frankenstein,* film [[Frankenstein (film Kevina Connora)]],sk.wikipedia.org/wiki/Frankenstein_(film_Kevina_Connora),* film [[Frankenstein (film Marcusa Nispela)]],sk.wikipedia.org/wiki/Frankenstein_(film_Marcusa_Nispela),* film [[Frankenstein (film Kennetha Branagha)]],sk.wikipedia.org/wiki/Frankenstein_(film_Kennetha_Branagha)\n'}>
#
#
# <Hit {'content': '351072,Moulin Rouge (rozlišovacia stránka),"* francúzsky kabaret v Paríži, pozri [[Moulin Rouge]]",sk.wikipedia.org/wiki/Moulin_Rouge,"* film z roku 2001, pozri [[Moulin Rouge (film z roku 2001)|Moulin Rouge! (film z roku 2001)]]",sk.wikipedia.org/wiki/Moulin_Rouge_(film_z_roku_2001),"* film z roku 1952, pozri [[Moulin Rouge (film z roku 1952)]]",sk.wikipedia.org/wiki/Moulin_Rouge_(film_z_roku_1952),"* film z roku 1934, pozri [[Moulin Rouge (film z roku 1934)]]",sk.wikipedia.org/wiki/Moulin_Rouge_(film_z_roku_1934),"* film z roku 1928, pozri [[Moulin Rouge (film z roku 1928)]]",sk.wikipedia.org/wiki/Moulin_Rouge_(film_z_roku_1928)\n'}>
#
#
# <Hit {'content': '448126,2012 (rozlišovacia stránka),"* rok, pozri [[2012]]",sk.wikipedia.org/wiki/2012,"* katastrofický film, pozri [[2012 (film)]]",sk.wikipedia.org/wiki/2012_(film)\n'}>
#
#
# <Hit {'content': '448468,Znásilnenie (rozlišovacia stránka),* [[znásilnenie]],sk.wikipedia.org/wiki/znásilnenie,"* film z roku 1988, pozri [[Znásilnenie (film)]]",sk.wikipedia.org/wiki/Znásilnenie_(film)\n'}>
#
#
# <Hit {'content': '533286,Mechanik (rozlišovacia stránka),"* povolanie, odborník na opravu, pozri [[mechanik]]",sk.wikipedia.org/wiki/mechanik,"* španielsky film z roku 2004, pozri [[Mechanik (film)]]",sk.wikipedia.org/wiki/Mechanik_(film)\n'}>
#
#
# <Hit {'content': '565883,Ilúzia (rozlišovacia stránka),"* skreslený vnem skutočnosti, pozri [[ilúzia]]",sk.wikipedia.org/wiki/ilúzia,"* československý televízny film z 1957, pozri [[Ilúzia (film)]]",sk.wikipedia.org/wiki/Ilúzia_(film)\n'}>
#
#
# <Hit {'content': '610530,Čiara (rozlišovacia stránka),"* nepretržitý, súvislý rad (sled) bodov, pozri [[čiara]]",sk.wikipedia.org/wiki/čiara,"* film z 2017, pozri [[Čiara (film)]]",sk.wikipedia.org/wiki/Čiara_(film)\n'}>
#
#
# <Hit {'content': '567635,Letisko (rozlišovacia stránka),"* štartovacia a pristávacia plocha pre lietadlá, pozri [[letisko]]",sk.wikipedia.org/wiki/letisko,"* film USA z 1970, pozri [[Letisko (film)]]",sk.wikipedia.org/wiki/Letisko_(film)\n'}>
#
#
# <Hit {'content': '584883,Hmla (rozlišovacia stránka),"* prízemné vodné pary, pozri [[hmla]]",sk.wikipedia.org/wiki/hmla,"* film z 2007 podľa knihy Stephena Kinga, pozri [[Hmla (film)]]",sk.wikipedia.org/wiki/Hmla_(film)\n'}>
#
#
# <Hit {'content': '629751,Bohemian Rhapsody (rozlišovacia stránka),"* skladba britskej rockovej skupiny Queen, pozri [[Bohemian Rhapsody]]",sk.wikipedia.org/wiki/Bohemian_Rhapsody,"* film z roku 2018, pozri [[Bohemian Rhapsody (film)]]",sk.wikipedia.org/wiki/Bohemian_Rhapsody_(film)\n'}>
